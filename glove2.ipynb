# %% [markdown]
# <a href="https://colab.research.google.com/github/alfinmaulani/skripsi/blob/master/glove2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import io
import os
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')


url1 = 'https://raw.githubusercontent.com/alfinmaulani/skripsi/master/dataisear(preputama).csv'
url2 = 'tba'
df = pd.read_csv(url1)
# df.iloc[:,1]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !pip install glove-python-binary
# Out:
# Collecting glove-python-binary
#   Downloading glove_python_binary-0.2.0-cp37-cp37m-manylinux1_x86_64.whl (948 kB)
#      |████████████████████████████████| 948 kB 35.3 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from glove-python-binary) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from glove-python-binary) (1.19.5)
# Installing collected packages: glove-python-binary
# Successfully installed glove-python-binary-0.2.0

# %%
from glove import Glove
from glove import Corpus

# %%
df.emosi.value_counts()
# Out:
# joy        1092
# sadness    1082
# anger      1079
# fear       1076
# shame      1071
# disgust    1066
# guilt      1050
# Name: emosi, dtype: int64

# %%
sentences = [word_tokenize(x) for x in df.dokumen]

# %%
df.dokumen
# Out:
# 0       on days when i feel close to my partner and ot...
# 1       every time i imagine that someone i love or i ...
# 2       when i had been obviously unjustly treated and...
# 3       when i think about the short time that we live...
# 4       at a gathering i found myself involuntarily si...
#                               ...
# 7511    two years back someone invited me to be the tu...
# 7512    i had taken the responsibility to do something...
# 7513    i was at home and i heard a loud sound of spit...
# 7514    i did not do the homework that the teacher had...
# 7515    i had shouted at my younger brother and he was...
# Name: dokumen, Length: 7516, dtype: object

# %%
korpus = Corpus()
korpus.fit(sentences, window=10, ignore_missing=False)
korpus.save('glove.model')

# %%
korpus.dictionary
# Out:
# {'on': 0,
#  'days': 1,
#  'when': 2,
#  'i': 3,
#  'feel': 4,
#  'close': 5,
#  'to': 6,
#  'my': 7,
#  'partner': 8,
#  'and': 9,
#  'other': 10,
#  'friends': 11,
#  'at': 12,
#  'peace': 13,
#  'with': 14,
#  'myself': 15,
#  'also': 16,
#  'experience': 17,
#  'a': 18,
#  'contact': 19,
#  'people': 20,
#  'whom': 21,
#  'regard': 22,
#  'greatly': 23,
#  'every': 24,
#  'time': 25,
#  'imagine': 26,
#  'that': 27,
#  'someone': 28,
#  'love': 29,
#  'or': 30,
#  'could': 31,
#  'serious': 32,
#  'illness': 33,
#  'even': 34,
#  'death': 35,
#  'had': 36,
#  'been': 37,
#  'obviously': 38,
#  'unjustly': 39,
#  'treated': 40,
#  'no': 41,
#  'possibility': 42,
#  'of': 43,
#  'elucidating': 44,
#  'this': 45,
#  'think': 46,
#  'about': 47,
#  'the': 48,
#  'short': 49,
#  'we': 50,
#  'live': 51,
#  'relate': 52,
#  'it': 53,
#  'periods': 54,
#  'life': 55,
#  'did': 56,
#  'not': 57,
#  'use': 58,
#  'gathering': 59,
#  'found': 60,
#  'involuntarily': 61,
#  'sitting': 62,
#  'next': 63,
#  'two': 64,
#  'who': 65,
#  'expressed': 66,
#  'opinions': 67,
#  'considered': 68,
#  'very': 69,
#  'low': 70,
#  'discriminating': 71,
#  'realized': 72,
#  'was': 73,
#  'directing': 74,
#  'feelings': 75,
#  'discontent': 76,
#  'way': 77,
#  'trying': 78,
#  'put': 79,
#  'blame': 80,
#  'him': 81,
#  'instead': 82,
#  'sorting': 83,
#  'out': 84,
#  'own': 85,
#  'feeliings': 86,
#  'guilty': 87,
#  'realize': 88,
#  'consider': 89,
#  'material': 90,
#  'things': 91,
#  'more': 92,
#  'important': 93,
#  'than': 94,
#  'caring': 95,
#  'for': 96,
#  'relatives': 97,
#  'selfcentered': 98,
#  'after': 99,
#  'girlfriend': 100,
#  'taken': 101,
#  'her': 102,
#  'exam': 103,
#  'went': 104,
#  'parents': 105,
#  'place': 106,
#  'first': 107,
#  'meaning': 108,
#  'car': 109,
#  'is': 110,
#  'overtaking': 111,
#  'another': 112,
#  'am': 113,
#  'forced': 114,
#  'drive': 115,
#  'off': 116,
#  'road': 117,
#  'recently': 118,
#  'thought': 119,
#  'hard': 120,
#  'work': 121,
#  'takes': 122,
#  'study': 123,
#  'how': 124,
#  'one': 125,
#  'wants': 126,
#  'try': 127,
#  'something': 128,
#  'else': 129,
#  'read': 130,
#  'theoretical': 131,
#  'book': 132,
#  'in': 133,
#  'english': 134,
#  'understand': 135,
#  'bristle': 136,
#  'liver': 137,
#  'paste': 138,
#  'tube': 139,
#  'tired': 140,
#  'unmotivated': 141,
#  'shouted': 142,
#  'brought': 143,
#  'up': 144,
#  'negative': 145,
#  'sides': 146,
#  'character': 147,
#  'which': 148,
#  'are': 149,
#  'actually': 150,
#  'so': 151,
#  'do': 152,
#  'enough': 153,
#  'weekend': 154,
#  'should': 155,
#  'have': 156,
#  'able': 157,
#  'accomplished': 158,
#  'during': 159,
#  'pass': 160,
#  'an': 161,
#  'examination': 162,
#  'well': 163,
#  'has': 164,
#  'arranged': 165,
#  'meet': 166,
#  'person': 167,
#  'arrives': 168,
#  'late': 169,
#  'meantime': 170,
#  'starts': 171,
#  'thinking': 172,
#  'all': 173,
#  'gone': 174,
#  'wrong': 175,
#  'eg': 176,
#  'traffic': 177,
#  'accident': 178,
#  'accused': 179,
#  'done': 180,
#  'ones': 181,
#  'studies': 182,
#  'seem': 183,
#  'hopelessly': 184,
#  'difficult': 185,
#  'uninteresting': 186,
#  'finds': 187,
#  'you': 188,
#  'know': 189,
#  'like': 190,
#  'instance': 191,
#  'steal': 192,
#  'quite': 193,
#  'unwarranted': 194,
#  'unjust': 195,
#  'stupid': 196,
#  'towards': 197,
#  'neglected': 198,
#  'good': 199,
#  'friend': 200,
#  'passing': 201,
#  'expect': 202,
#  'climbed': 203,
#  'tree': 204,
#  'pick': 205,
#  'apples': 206,
#  'angle': 207,
#  'ladder': 208,
#  'enable': 209,
#  'me': 210,
#  'get': 211,
#  'high': 212,
#  'implied': 213,
#  'stable': 214,
#  'excuses': 215,
#  'necessary': 216,
#  'doing': 217,
#  'children': 218,
#  '2': 219,
#  'year': 220,
#  'old': 221,
#  'son': 222,
#  'sat': 223,
#  '7th': 224,
#  'floor': 225,
#  'balcony': 226,
#  'his': 227,
#  'legs': 228,
#  'hanging': 229,
#  'he': 230,
#  'holding': 231,
#  'tightly': 232,
#  'upper': 233,
#  'railing': 234,
#  'but': 235,
#  'easily': 236,
#  'lost': 237,
#  'balance': 238,
#  'down': 239,
#  'attacked': 240,
#  'three': 241,
#  'teeth': 242,
#  'see': 243,
#  'tv': 244,
#  'from': 245,
#  'areas': 246,
#  'devastated': 247,
#  'by': 248,
#  'drought': 249,
#  'war': 250,
#  'nearly': 251,
#  'walked': 252,
#  'blindworm': 253,
#  'then': 254,
#  'saw': 255,
#  'crawl': 256,
#  'away': 257,
#  '18': 258,
#  'grab': 259,
#  'oxygen': 260,
#  'mask': 261,
#  'as': 262,
#  'breathing': 263,
#  'difficulties': 264,
#  'bad': 265,
#  'conscience': 266,
#  'because': 267,
#  'stopped': 268,
#  'smoking': 269,
#  'medication': 270,
#  'dilation': 271,
#  'tubes': 272,
#  'caused': 273,
#  'sense': 274,
#  'guilt': 275,
#  'middle': 276,
#  'can': 277,
#  'express': 278,
#  'himself': 279,
#  'neither': 280,
#  'verbally': 281,
#  'nor': 282,
#  'writing': 283,
#  'child': 284,
#  'born': 285,
#  'spring': 286,
#  'ice': 287,
#  'melting': 288,
#  'far': 289,
#  'jetty': 290,
#  'poked': 291,
#  'long': 292,
#  'branch': 293,
#  'break': 294,
#  'through': 295,
#  'fell': 296,
#  'water': 297,
#  'closed': 298,
#  'over': 299,
#  'head': 300,
#  'accusations': 301,
#  'directed': 302,
#  'acting': 303,
#  'failing': 304,
#  'drunkard': 305,
#  'started': 306,
#  'bleeding': 307,
#  'wet': 308,
#  'disgust': 309,
#  'turned': 310,
#  'into': 311,
#  'sadnessunpleasantness': 312,
#  'adult': 313,
#  'caught': 314,
#  'lying': 315,
#  'behaving': 316,
#  'badly': 317,
#  'environment': 318,
#  'much': 319,
#  'worse': 320,
#  'privileged': 321,
#  'seen': 322,
#  'knocked': 323,
#  'heard': 324,
#  'radio': 325,
#  'football': 326,
#  'match': 327,
#  'belgium': 328,
#  'ended': 329,
#  'catastrophe': 330,
#  'several': 331,
#  'died': 332,
#  'normal': 333,
#  'behave': 334,
#  'such': 335,
#  'lonely': 336,
#  'perhaps': 337,
#  'lot': 338,
#  'shut': 339,
#  'appartment': 340,
#  'nothing': 341,
#  'happens': 342,
#  'particular': 343,
#  'there': 344,
#  'anything': 345,
#  'learns': 346,
#  'mass': 347,
#  'media': 348,
#  'wars': 349,
#  'killing': 350,
#  'going': 351,
#  'world': 352,
#  'lied': 353,
#  'be': 354,
#  'precise': 355,
#  'cancelled': 356,
#  'meeting': 357,
#  'lets': 358,
#  'accepted': 359,
#  'course': 360,
#  'finance': 361,
#  'accounting': 362,
#  'bus': 363,
#  'drove': 364,
#  'right': 365,
#  'leg': 366,
#  'event': 367,
#  'itself': 368,
#  'frightening': 369,
#  'wait': 370,
#  'emergency': 371,
#  'ward': 372,
#  'hours': 373,
#  'began': 374,
#  'swell': 375,
#  'frightened': 376,
#  'summer': 377,
#  'job': 378,
#  'nobody': 379,
#  'looked': 380,
#  'learn': 381,
#  'student': 382,
#  'just': 383,
#  'moved': 384,
#  'new': 385,
#  'ventilator': 386,
#  'kitchen': 387,
#  'clean': 388,
#  'drum': 389,
#  'full': 390,
#  'mud': 391,
#  'slime': 392,
#  'felt': 393,
#  'disgusted': 394,
#  'elder': 395,
#  'brother': 396,
#  'always': 397,
#  'relationship': 398,
#  'ashamed': 399,
#  'call': 400,
#  'talk': 401,
#  'nowadays': 402,
#  'caretaker': 403,
#  'employed': 404,
#  'age': 405,
#  'preferred': 406,
#  'lunch': 407,
#  'accounts': 408,
#  'personnel': 409,
#  'rather': 410,
#  'passed': 411,
#  'points': 412,
#  'cottage': 413,
#  'large': 414,
#  'forest': 415,
#  'alone': 416,
#  'while': 417,
#  'dark': 418,
#  'railway': 419,
#  'station': 420,
#  'goodbye': 421,
#  'cripple': 422,
#  'rags': 423,
#  'small': 424,
#  'italy': 425,
#  'probably': 426,
#  'imposter': 427,
#  'told': 428,
#  'party': 429,
#  'would': 430,
#  'enjoy': 431,
#  'if': 432,
#  'came': 433,
#  'along': 434,
#  'understood': 435,
#  'fitted': 436,
#  'reason': 437,
#  'behind': 438,
#  'breakup': 439,
#  'she': 440,
#  'finished': 441,
#  'absolutely': 442,
#  'certain': 443,
#  'failed': 444,
#  'back': 445,
#  'denmark': 446,
#  'yatch': 447,
#  'storm': 448,
#  'blown': 449,
#  'overboard': 450,
#  'scared': 451,
#  'till': 452,
#  'managed': 453,
#  'onboard': 454,
#  'locked': 455,
#  'missed': 456,
#  'last': 457,
#  'tram': 458,
#  'home': 459,
#  'walk': 460,
#  'pouring': 461,
#  'rain': 462,
#  'some': 463,
#  'worms': 464,
#  'food': 465,
#  'eaten': 466,
#  'intoxicated': 467,
#  'police': 468,
#  'took': 469,
#  'they': 470,
#  'later': 471,
#  'contacted': 472,
#  'hapened': 473,
#  'overhear': 474,
#  'meant': 475,
#  'hear': 476,
#  'won': 477,
#  'trip': 478,
#  'greece': 479,
#  'competition': 480,
#  'suspicious': 481,
#  'looking': 482,
#  'comes': 483,
#  'elderly': 484,
#  'man': 485,
#  'complained': 486,
#  'unjustifiably': 487,
#  'distrusted': 488,
#  'lecture': 489,
#  'alcoholic': 490,
#  'stood': 491,
#  'dribbling': 492,
#  'counter': 493,
#  'were': 494,
#  'discussing': 495,
#  'looks': 496,
#  'guy': 497,
#  'listening': 498,
#  'colleague': 499,
#  'manager': 500,
#  'believing': 501,
#  'liked': 502,
#  'birthday': 503,
#  'closest': 504,
#  'pleasant': 505,
#  'say': 506,
#  'happy': 507,
#  'friday': 508,
#  'night': 509,
#  'heavy': 510,
#  'acquaplanned': 511,
#  'surface': 512,
#  'few': 513,
#  'seconds': 514,
#  'mad': 515,
#  'dad': 516,
#  'case': 517,
#  'unrequited': 518,
#  'smelling': 519,
#  'cucumber': 520,
#  'masturbating': 521,
#  'help': 522,
#  'pools': 523,
#  'flew': 524,
#  'athens': 525,
#  'copenhagen': 526,
#  'holiday': 527,
#  'plane': 528,
#  'shake': 529,
#  'thouhght': 530,
#  'crash': 531,
#  'stole': 532,
#  'bike': 533,
#  'list': 534,
#  'books': 535,
#  'acccouting': 536,
#  'oh': 537,
#  'god': 538,
#  'will': 539,
#  'ever': 540,
#  'manaage': 541,
#  'newspaper': 542,
#  'article': 543,
#  'future': 544,
#  'foresaw': 545,
#  'eating': 546,
#  'frogburgers': 547,
#  '2000': 548,
#  'illustration': 549,
#  'showed': 550,
#  'frog': 551,
#  'between': 552,
#  'pieces': 553,
#  'bread': 554,
#  'dropped': 555,
#  'bottle': 556,
#  'state': 557,
#  'liquor': 558,
#  'store': 559,
#  'everyboby': 560,
#  'laughing': 561,
#  'young': 562,
#  '14': 563,
#  'pinched': 564,
#  'whole': 565,
#  'family': 566,
#  'gets': 567,
#  'together': 568,
#  'week': 569,
#  'everybody': 570,
#  'feels': 571,
#  'free': 572,
#  'planned': 573,
#  'works': 574,
#  'ourselves': 575,
#  'find': 576,
#  'daughter': 577,
#  'ran': 578,
#  'everywhere': 579,
#  'finally': 580,
#  'bed': 581,
#  'sleep': 582,
#  'hurt': 583,
#  'marriage': 584,
#  'crises': 585,
#  'boredom': 586,
#  'makes': 587,
#  'advances': 588,
#  'does': 589,
#  'want': 590,
#  'discovery': 591,
#  'only': 592,
#  'oneself': 593,
#  'spanked': 594,
#  'anger': 595,
#  'regretted': 596,
#  'terribly': 597,
#  'repeat': 598,
#  'stockholm': 599,
#  'stora': 600,
#  'hissingen': 601,
#  'exit': 602,
#  'boyfriend': 603,
#  'month': 604,
#  'without': 605,
#  'worked': 606,
#  'holidays': 607,
#  'studied': 608,
#  'same': 609,
#  'dog': 610,
#  'left': 611,
#  'whining': 612,
#  'outside': 613,
#  'shop': 614,
#  'promised': 615,
#  'keep': 616,
#  'promise': 617,
#  'examinations': 618,
#  'take': 619,
#  'day': 620,
#  'economics': 621,
#  'taking': 622,
#  'cut': 623,
#  'vasa': 624,
#  'park': 625,
#  'surrounded': 626,
#  'tried': 627,
#  'money': 628,
#  'saved': 629,
#  'appearance': 630,
#  'restaurant': 631,
#  'observed': 632,
#  'gypsies': 633,
#  'cheating': 634,
#  'foreigners': 635,
#  'ie': 636,
#  'non': 637,
#  'swedish': 638,
#  'speaking': 639,
#  'hatred': 640,
#  'against': 641,
#  'expression': 642,
#  'being': 643,
#  'used': 644,
#  'begining': 645,
#  'afraid': 646,
#  'encountering': 647,
#  'problems': 648,
#  'manage': 649,
#  'thoughts': 650,
#  'revolve': 651,
#  'around': 652,
#  'subject': 653,
#  'consequences': 654,
#  'walking': 655,
#  'town': 656,
#  'noticed': 657,
#  'harrassed': 658,
#  'under': 659,
#  'influence': 660,
#  'alcohol': 661,
#  'terrified': 662,
#  'arrest': 663,
#  'driving': 664,
#  'pedestrian': 665,
#  'street': 666,
#  'gestures': 667,
#  'facial': 668,
#  'expressions': 669,
#  'policemen': 670,
#  'seemed': 671,
#  'enjoying': 672,
#  'themselves': 673,
#  'revealed': 674,
#  'knew': 675,
#  'discovered': 676,
#  'nature': 677,
#  'mentioned': 678,
#  'earlier': 679,
#  'dishonest': 680,
#  'gives': 681,
#  'different': 682,
#  'version': 683,
#  'truth': 684,
#  'corrected': 685,
#  'these': 686,
#  'mistakes': 687,
#  'aware': 688,
#  'exams': 689,
#  'margin': 690,
#  'marks': 691,
#  'father': 692,
#  'ill': 693,
#  'waiting': 694,
#  'results': 695,
#  'tests': 696,
#  'got': 697,
#  'thursday': 698,
#  'raincoat': 699,
#  'prepared': 700,
#  'contribution': 701,
#  'group': 702,
#  'thoroughly': 703,
#  'members': 704,
#  'result': 705,
#  'overall': 706,
#  'poor': 707,
#  'house': 708,
#  'recovered': 709,
#  'lazy': 710,
#  'gave': 711,
#  'birth': 712,
#  'alive': 713,
#  'too': 714,
#  'early': 715,
#  'malfunctioning': 716,
#  'lung': 717,
#  'happened': 718,
#  'ago': 719,
#  'cancer': 720,
#  'asked': 721,
#  'despite': 722,
#  'fact': 723,
#  'salary': 724,
#  'increase': 725,
#  'expecting': 726,
#  'little': 727,
#  'appreciated': 728,
#  'weeding': 729,
#  'garden': 730,
#  'lizard': 731,
#  'hand': 732,
#  'met': 733,
#  'troubles': 734,
#  'touch': 735,
#  'angry': 736,
#  'mother': 737,
#  'trivial': 738,
#  'mood': 739,
#  'really': 740,
#  'needed': 741,
#  'support': 742,
#  'reacted': 743,
#  'wrongly': 744,
#  'years': 745,
#  'eve': 746,
#  '19831984': 747,
#  'steps': 748,
#  'kissed': 749,
#  'plain': 750,
#  'clothes': 751,
#  'overturned': 752,
#  'avenue': 753,
#  'fast': 754,
#  'questionned': 755,
#  'toild': 756,
#  'go': 757,
#  'situation': 758,
#  'happily': 759,
#  'since': 760,
#  'editor': 761,
#  'changed': 762,
#  'heading': 763,
#  'written': 764,
#  'derogatory': 765,
#  'acquaintance': 766,
#  'although': 767,
#  'expected': 768,
#  'still': 769,
#  'depressed': 770,
#  'picture': 771,
#  'gothenburg': 772,
#  'post': 773,
#  'totally': 774,
#  'demolished': 775,
#  'fatally': 776,
#  'injured': 777,
#  'passengers': 778,
#  'damaged': 779,
#  'couldnt': 780,
#  'bodies': 781,
#  'scene': 782,
#  'sexual': 783,
#  'intercourse': 784,
#  'desire': 785,
#  'curiosity': 786,
#  'made': 787,
#  'jump': 788,
#  'now': 789,
#  'due': 790,
#  'laziness': 791,
#  'term': 792,
#  'completely': 793,
#  'university': 794,
#  'wanted': 795,
#  'extent': 796,
#  'protest': 797,
#  'expectations': 798,
#  'loan': 799,
#  'dubious': 800,
#  'intentions': 801,
#  'alley': 802,
#  'wednesday': 803,
#  'news': 804,
#  'feature': 805,
#  'south': 806,
#  'africa': 807,
#  'policeman': 808,
#  'black': 809,
#  'whip': 810,
#  'having': 811,
#  'boring': 812,
#  '400': 813,
#  'pages': 814,
#  'grovelling': 815,
#  'inability': 816,
#  'assert': 817,
#  'positively': 818,
#  'observing': 819,
#  'cafeteria': 820,
#  'noisily': 821,
#  'gulping': 822,
#  'extremely': 823,
#  'manners': 824,
#  'guess': 825,
#  'often': 826,
#  'talked': 827,
#  'unpleasant': 828,
#  'sister': 829,
#  'history': 830,
#  'abortion': 831,
#  'stillbirth': 832,
#  'perfectly': 833,
#  'healty': 834,
#  'boy': 835,
#  'emotionally': 836,
#  'deep': 837,
#  'recover': 838,
#  'starting': 839,
#  'project': 840,
#  'teacher': 841,
#  'helpful': 842,
#  'openly': 843,
#  'let': 844,
#  'preferring': 845,
#  'girl': 846,
#  'cant': 847,
#  'any': 848,
#  'before': 849,
#  'aunt': 850,
#  'offered': 851,
#  'front': 852,
#  'seat': 853,
#  'driver': 854,
#  'declined': 855,
#  'killed': 856,
#  'crashed': 857,
#  'unexpected': 858,
#  'visit': 859,
#  'hadnt': 860,
#  'half': 861,
#  'wandered': 862,
#  'mistake': 863,
#  'safety': 864,
#  'zone': 865,
#  'shooting': 866,
#  'range': 867,
#  'shot': 868,
#  'unfairly': 869,
#  'breaking': 870,
#  'none': 871,
#  'college': 872,
#  'possible': 873,
#  'arrive': 874,
#  'school': 875,
#  'grandmother': 876,
#  'applicable': 877,
#  'couple': 878,
#  'fishing': 879,
#  'lake': 880,
#  'husband': 881,
#  'suddenly': 882,
#  'raining': 883,
#  'sun': 884,
#  'shining': 885,
#  'experienced': 886,
#  'feeling': 887,
#  'joy': 888,
#  'happiness': 889,
#  'fulfillment': 890,
#  'music': 891,
#  'reading': 892,
#  'womens': 893,
#  'magazine': 894,
#  'storiees': 895,
#  'paranormal': 896,
#  'experiences': 897,
#  'itching': 898,
#  'stretched': 899,
#  'scratch': 900,
#  'strange': 901,
#  'corner': 902,
#  'blanket': 903,
#  'once': 904,
#  'again': 905,
#  'second': 906,
#  'attitude': 907,
#  'lecturer': 908,
#  'former': 909,
#  'superior': 910,
#  'mine': 911,
#  'our': 912,
#  'interaction': 913,
#  'longer': 914,
#  'limited': 915,
#  'scope': 916,
#  'human': 917,
#  'sad': 918,
#  'fat': 919,
#  'sickly': 920,
#  'woman': 921,
#  'asking': 922,
#  'directions': 923,
#  'thick': 924,
#  'voice': 925,
#  'disgusting': 926,
#  'smell': 927,
#  'urine': 928,
#  'choke': 929,
#  'remark': 930,
#  'friendly': 931,
#  'manner': 932,
#  'deed': 933,
#  'therefore': 934,
#  'shame': 935,
#  'concerning': 936,
#  'men': 937,
#  'compared': 938,
#  'evening': 939,
#  'sadness': 940,
#  'sweden': 941,
#  'practice': 942,
#  'association': 943,
#  'pals': 944,
#  'wake': 945,
#  'morning': 946,
#  'bringing': 947,
#  'played': 948,
#  'highest': 949,
#  'volume': 950,
#  'room': 951,
#  'service': 952,
#  'its': 953,
#  'loudest': 954,
#  'swindled': 955,
#  'customers': 956,
#  'detest': 957,
#  'arrived': 958,
#  'bank': 959,
#  'feeble': 960,
#  'polish': 961,
#  'visitors': 962,
#  'boat': 963,
#  'them': 964,
#  'chairman': 965,
#  'unexpectedly': 966,
#  'become': 967,
#  'vicechairman': 968,
#  'organisation': 969,
#  'surprised': 970,
#  'emotion': 971,
#  'though': 972,
#  'worry': 973,
#  'shall': 974,
#  'succeed': 975,
#  'tutorial': 976,
#  'soon': 977,
#  'divided': 978,
#  'names': 979,
#  'freshmen': 980,
#  'five': 981,
#  'each': 982,
#  'seminar': 983,
#  'wondered': 984,
#  'cope': 985,
#  'leader': 986,
#  'disco': 987,
#  'knowing': 988,
#  'why': 989,
#  'companion': 990,
#  'humour': 991,
#  'hide': 992,
#  'called': 993,
#  'sunday': 994,
#  'autumn': 995,
#  'hated': 996,
#  'moment': 997,
#  'sounded': 998,
#  'remained': 999,
#  ...}

# %%
corpus_model = Corpus.load('glove.model')

# %%
glove = Glove()
glove.fit(corpus_model.matrix)
glove.add_dictionary(corpus_model.dictionary)
glove.save('glove.model')

# %%
glove
